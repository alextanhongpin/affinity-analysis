# %%
# Another implementation of Apriori, based on the book Machine Learning in Action

# %%
def load_dataset():
#     return [[1, 3, 4], 
#             [2, 3, 5],
#             [1, 2, 3, 5],
#             [2, 5]]
    return [['Mango', 'Onion', 'Nintendo', 'Key-chain', 'Eggs', 'Yo-yo'],
           ['Doll', 'Onion', 'Nintendo', 'Key-chain', 'Eggs', 'Yo-yo'],
           ['Mango', 'Apple', 'Key-chain', 'Eggs'],
           ['Mango', 'Umbrella', 'Corn', 'Key-chain', 'Yo-yo'],
           ['Corn', 'Onion', 'Onion', 'Key-chain', 'Ice-cream', 'Eggs']]

# %%
def create_candidates(dataset):
    candidates = []
    for transaction in dataset:
        for item in transaction:
            if not [item] in candidates:
                candidates.append([item])
#     candidates.sort()
    return map(frozenset, candidates)

# %%
def scan_dataset(dataset, candidates, min_support):
    subset_candidate = {}
    output = []
    support_data = {}
    num_items = float(len(dataset))

    for trans_id in dataset:
        for candidate in candidates:
            if candidate.issubset(trans_id):
                if not subset_candidate.get(candidate):
                    subset_candidate[candidate] = 1
                else:
                    subset_candidate[candidate] += 1

    for key in subset_candidate:
        support = subset_candidate[key] / num_items
        if support >= min_support:
            output.append(key)
        support_data[key] = support
    return output, support_data

# %%
def apriori_generate(itemset, k):
    output = []
    len_itemset = len(itemset)
    for i in range(len_itemset):
        for j in range(i + 1, len_itemset):
            itemset_1 = list(itemset[i])[:k-2]
            itemset_2 = list(itemset[j])[:k-2]
            itemset_1.sort()
            itemset_2.sort()
            if itemset_1 == itemset_2:
                output.append(itemset[i] | itemset[j])
    return output

# %%
def apriori(dataset, min_support = 0.2):
    candidates = create_candidates(dataset)
    data = list(map(set, dataset))
    itemset_1, support = scan_dataset(data, candidates, min_support)
    itemsets = [itemset_1]
    k = 2
    while len(itemsets[k - 2]) > 0:
        candidates_k = apriori_generate(itemsets[k - 2], k)
        itemsets_k, support_k = scan_dataset(data, candidates_k, min_support)
        support.update(support_k)
        itemsets.append(itemsets_k)
        k += 1
    return itemsets, support

itemsets, support_data = apriori(load_dataset())
print('itemsets:', itemsets)
print()
print('support_data:', support_data)
# Out:
# itemsets: [[frozenset({'Mango'}), frozenset({'Onion'}), frozenset({'Nintendo'}), frozenset({'Key-chain'}), frozenset({'Eggs'}), frozenset({'Yo-yo'})], [frozenset({'Onion', 'Mango'}), frozenset({'Nintendo', 'Mango'}), frozenset({'Mango', 'Key-chain'}), frozenset({'Mango', 'Eggs'}), frozenset({'Mango', 'Yo-yo'}), frozenset({'Onion', 'Nintendo'}), frozenset({'Onion', 'Key-chain'}), frozenset({'Onion', 'Eggs'}), frozenset({'Onion', 'Yo-yo'}), frozenset({'Nintendo', 'Key-chain'}), frozenset({'Nintendo', 'Eggs'}), frozenset({'Nintendo', 'Yo-yo'}), frozenset({'Eggs', 'Key-chain'}), frozenset({'Key-chain', 'Yo-yo'}), frozenset({'Eggs', 'Yo-yo'})], [frozenset({'Nintendo', 'Onion', 'Mango'}), frozenset({'Onion', 'Mango', 'Key-chain'}), frozenset({'Onion', 'Mango', 'Eggs'}), frozenset({'Onion', 'Mango', 'Yo-yo'}), frozenset({'Nintendo', 'Mango', 'Key-chain'}), frozenset({'Nintendo', 'Mango', 'Eggs'}), frozenset({'Nintendo', 'Mango', 'Yo-yo'}), frozenset({'Eggs', 'Mango', 'Key-chain'}), frozenset({'Mango', 'Key-chain', 'Yo-yo'}), frozenset({'Mango', 'Eggs', 'Yo-yo'}), frozenset({'Onion', 'Nintendo', 'Key-chain'}), frozenset({'Onion', 'Nintendo', 'Eggs'}), frozenset({'Onion', 'Nintendo', 'Yo-yo'}), frozenset({'Onion', 'Eggs', 'Key-chain'}), frozenset({'Onion', 'Key-chain', 'Yo-yo'}), frozenset({'Onion', 'Eggs', 'Yo-yo'}), frozenset({'Eggs', 'Nintendo', 'Key-chain'}), frozenset({'Nintendo', 'Key-chain', 'Yo-yo'}), frozenset({'Nintendo', 'Eggs', 'Yo-yo'}), frozenset({'Eggs', 'Key-chain', 'Yo-yo'})], [frozenset({'Onion', 'Mango', 'Key-chain', 'Nintendo'}), frozenset({'Onion', 'Mango', 'Eggs', 'Nintendo'}), frozenset({'Onion', 'Mango', 'Nintendo', 'Yo-yo'}), frozenset({'Onion', 'Mango', 'Key-chain', 'Eggs'}), frozenset({'Onion', 'Mango', 'Key-chain', 'Yo-yo'}), frozenset({'Onion', 'Mango', 'Eggs', 'Yo-yo'}), frozenset({'Mango', 'Key-chain', 'Eggs', 'Nintendo'}), frozenset({'Mango', 'Key-chain', 'Nintendo', 'Yo-yo'}), frozenset({'Mango', 'Eggs', 'Nintendo', 'Yo-yo'}), frozenset({'Mango', 'Eggs', 'Key-chain', 'Yo-yo'}), frozenset({'Onion', 'Key-chain', 'Eggs', 'Nintendo'}), frozenset({'Onion', 'Key-chain', 'Nintendo', 'Yo-yo'}), frozenset({'Onion', 'Eggs', 'Nintendo', 'Yo-yo'}), frozenset({'Onion', 'Eggs', 'Key-chain', 'Yo-yo'}), frozenset({'Eggs', 'Key-chain', 'Nintendo', 'Yo-yo'})], [frozenset({'Mango', 'Nintendo', 'Onion', 'Key-chain', 'Eggs'}), frozenset({'Mango', 'Nintendo', 'Onion', 'Key-chain', 'Yo-yo'}), frozenset({'Mango', 'Nintendo', 'Onion', 'Eggs', 'Yo-yo'}), frozenset({'Mango', 'Onion', 'Eggs', 'Key-chain', 'Yo-yo'}), frozenset({'Mango', 'Nintendo', 'Eggs', 'Key-chain', 'Yo-yo'}), frozenset({'Nintendo', 'Onion', 'Eggs', 'Key-chain', 'Yo-yo'})], [frozenset({'Mango', 'Nintendo', 'Onion', 'Key-chain', 'Eggs', 'Yo-yo'})], []]
#
# support_data: {frozenset({'Mango'}): 0.2, frozenset({'Onion'}): 0.2, frozenset({'Nintendo'}): 0.2, frozenset({'Key-chain'}): 0.2, frozenset({'Eggs'}): 0.2, frozenset({'Yo-yo'}): 0.2, frozenset({'Onion', 'Mango'}): 0.2, frozenset({'Nintendo', 'Mango'}): 0.2, frozenset({'Mango', 'Key-chain'}): 0.6, frozenset({'Mango', 'Eggs'}): 0.4, frozenset({'Mango', 'Yo-yo'}): 0.4, frozenset({'Onion', 'Nintendo'}): 0.4, frozenset({'Onion', 'Key-chain'}): 0.6, frozenset({'Onion', 'Eggs'}): 0.6, frozenset({'Onion', 'Yo-yo'}): 0.4, frozenset({'Nintendo', 'Key-chain'}): 0.4, frozenset({'Nintendo', 'Eggs'}): 0.4, frozenset({'Nintendo', 'Yo-yo'}): 0.4, frozenset({'Eggs', 'Key-chain'}): 0.8, frozenset({'Key-chain', 'Yo-yo'}): 0.6, frozenset({'Eggs', 'Yo-yo'}): 0.4, frozenset({'Nintendo', 'Onion', 'Mango'}): 0.2, frozenset({'Onion', 'Mango', 'Key-chain'}): 0.2, frozenset({'Onion', 'Mango', 'Eggs'}): 0.2, frozenset({'Onion', 'Mango', 'Yo-yo'}): 0.2, frozenset({'Nintendo', 'Mango', 'Key-chain'}): 0.2, frozenset({'Nintendo', 'Mango', 'Eggs'}): 0.2, frozenset({'Nintendo', 'Mango', 'Yo-yo'}): 0.2, frozenset({'Eggs', 'Mango', 'Key-chain'}): 0.4, frozenset({'Mango', 'Key-chain', 'Yo-yo'}): 0.4, frozenset({'Mango', 'Eggs', 'Yo-yo'}): 0.2, frozenset({'Onion', 'Nintendo', 'Key-chain'}): 0.4, frozenset({'Onion', 'Nintendo', 'Eggs'}): 0.4, frozenset({'Onion', 'Nintendo', 'Yo-yo'}): 0.4, frozenset({'Onion', 'Eggs', 'Key-chain'}): 0.6, frozenset({'Onion', 'Key-chain', 'Yo-yo'}): 0.4, frozenset({'Onion', 'Eggs', 'Yo-yo'}): 0.4, frozenset({'Eggs', 'Nintendo', 'Key-chain'}): 0.4, frozenset({'Nintendo', 'Key-chain', 'Yo-yo'}): 0.4, frozenset({'Nintendo', 'Eggs', 'Yo-yo'}): 0.4, frozenset({'Eggs', 'Key-chain', 'Yo-yo'}): 0.4, frozenset({'Onion', 'Mango', 'Key-chain', 'Nintendo'}): 0.2, frozenset({'Onion', 'Mango', 'Eggs', 'Nintendo'}): 0.2, frozenset({'Onion', 'Mango', 'Nintendo', 'Yo-yo'}): 0.2, frozenset({'Onion', 'Mango', 'Key-chain', 'Eggs'}): 0.2, frozenset({'Onion', 'Mango', 'Key-chain', 'Yo-yo'}): 0.2, frozenset({'Onion', 'Mango', 'Eggs', 'Yo-yo'}): 0.2, frozenset({'Mango', 'Key-chain', 'Eggs', 'Nintendo'}): 0.2, frozenset({'Mango', 'Key-chain', 'Nintendo', 'Yo-yo'}): 0.2, frozenset({'Mango', 'Eggs', 'Nintendo', 'Yo-yo'}): 0.2, frozenset({'Mango', 'Eggs', 'Key-chain', 'Yo-yo'}): 0.2, frozenset({'Onion', 'Key-chain', 'Eggs', 'Nintendo'}): 0.4, frozenset({'Onion', 'Key-chain', 'Nintendo', 'Yo-yo'}): 0.4, frozenset({'Onion', 'Eggs', 'Nintendo', 'Yo-yo'}): 0.4, frozenset({'Onion', 'Eggs', 'Key-chain', 'Yo-yo'}): 0.4, frozenset({'Eggs', 'Key-chain', 'Nintendo', 'Yo-yo'}): 0.4, frozenset({'Mango', 'Nintendo', 'Onion', 'Key-chain', 'Eggs'}): 0.2, frozenset({'Mango', 'Nintendo', 'Onion', 'Key-chain', 'Yo-yo'}): 0.2, frozenset({'Mango', 'Nintendo', 'Onion', 'Eggs', 'Yo-yo'}): 0.2, frozenset({'Mango', 'Onion', 'Eggs', 'Key-chain', 'Yo-yo'}): 0.2, frozenset({'Mango', 'Nintendo', 'Eggs', 'Key-chain', 'Yo-yo'}): 0.2, frozenset({'Nintendo', 'Onion', 'Eggs', 'Key-chain', 'Yo-yo'}): 0.4, frozenset({'Mango', 'Nintendo', 'Onion', 'Key-chain', 'Eggs', 'Yo-yo'}): 0.2}

# %%
# {a -> b}, a = antecedent, b = consequent

def generate_rules(itemsets, support_data, min_confidence = 0.7):
    big_rule_list = []
    for i in range(1, len(itemsets)):
        for freq_set in itemsets[i]:
            h_1 = [frozenset([item]) for item in freq_set]
            if i > 1:
                rules_from_consequent(freq_set, h_1, support_data, big_rule_list, min_confidence)
            else:
                calculate_confidence(freq_set, h_1, support_data, big_rule_list, min_confidence)
    return big_rule_list

# %%
def calculate_confidence(freq_set, h, support_data, big_rule_list, min_confidence = 0.7):
    pruned_h = []
    for consequent in h:
        confidence = support_data[freq_set] / support_data[freq_set - consequent]
        if confidence >= min_confidence:
            print('{} ---> {}, conf: {}'.format(freq_set - consequent, consequent, confidence))
            big_rule_list.append((freq_set - consequent, consequent, confidence))
            pruned_h.append(consequent)
    return pruned_h

# %%
def rules_from_consequent(freq_set, h, support_data, big_rule_list, min_confidence = 0.7):
    m = len(h[0])
    if len(freq_set) > (m + 1):
        hmp1 = apriori_generate(h, m + 1)
        hmp1 = calculate_confidence(freq_set, hmp1, support_data, big_rule_list, min_confidence)
        if len(hmp1) > 1:
            rules_from_consequent(freq_set, hmp1, support_data, big_rule_list, min_confidence)

# %%
rules = generate_rules(itemsets, support_data, min_confidence = 0.7)
rules
# Out:
# frozenset({'Mango'}) ---> frozenset({'Onion'}), conf: 1.0
# frozenset({'Onion'}) ---> frozenset({'Mango'}), conf: 1.0
# frozenset({'Mango'}) ---> frozenset({'Nintendo'}), conf: 1.0
# frozenset({'Nintendo'}) ---> frozenset({'Mango'}), conf: 1.0
# frozenset({'Key-chain'}) ---> frozenset({'Mango'}), conf: 2.9999999999999996
# frozenset({'Mango'}) ---> frozenset({'Key-chain'}), conf: 2.9999999999999996
# frozenset({'Eggs'}) ---> frozenset({'Mango'}), conf: 2.0
# frozenset({'Mango'}) ---> frozenset({'Eggs'}), conf: 2.0
# frozenset({'Yo-yo'}) ---> frozenset({'Mango'}), conf: 2.0
# frozenset({'Mango'}) ---> frozenset({'Yo-yo'}), conf: 2.0
# frozenset({'Nintendo'}) ---> frozenset({'Onion'}), conf: 2.0
# frozenset({'Onion'}) ---> frozenset({'Nintendo'}), conf: 2.0
# frozenset({'Key-chain'}) ---> frozenset({'Onion'}), conf: 2.9999999999999996
# frozenset({'Onion'}) ---> frozenset({'Key-chain'}), conf: 2.9999999999999996
# frozenset({'Eggs'}) ---> frozenset({'Onion'}), conf: 2.9999999999999996
# frozenset({'Onion'}) ---> frozenset({'Eggs'}), conf: 2.9999999999999996
# frozenset({'Yo-yo'}) ---> frozenset({'Onion'}), conf: 2.0
# frozenset({'Onion'}) ---> frozenset({'Yo-yo'}), conf: 2.0
# frozenset({'Key-chain'}) ---> frozenset({'Nintendo'}), conf: 2.0
# frozenset({'Nintendo'}) ---> frozenset({'Key-chain'}), conf: 2.0
# frozenset({'Eggs'}) ---> frozenset({'Nintendo'}), conf: 2.0
# frozenset({'Nintendo'}) ---> frozenset({'Eggs'}), conf: 2.0
# frozenset({'Yo-yo'}) ---> frozenset({'Nintendo'}), conf: 2.0
# frozenset({'Nintendo'}) ---> frozenset({'Yo-yo'}), conf: 2.0
# frozenset({'Key-chain'}) ---> frozenset({'Eggs'}), conf: 4.0
# frozenset({'Eggs'}) ---> frozenset({'Key-chain'}), conf: 4.0
# frozenset({'Yo-yo'}) ---> frozenset({'Key-chain'}), conf: 2.9999999999999996
# frozenset({'Key-chain'}) ---> frozenset({'Yo-yo'}), conf: 2.9999999999999996
# frozenset({'Yo-yo'}) ---> frozenset({'Eggs'}), conf: 2.0
# frozenset({'Eggs'}) ---> frozenset({'Yo-yo'}), conf: 2.0
# frozenset({'Mango'}) ---> frozenset({'Onion', 'Nintendo'}), conf: 1.0
# frozenset({'Onion'}) ---> frozenset({'Nintendo', 'Mango'}), conf: 1.0
# frozenset({'Nintendo'}) ---> frozenset({'Onion', 'Mango'}), conf: 1.0
# frozenset({'Key-chain'}) ---> frozenset({'Onion', 'Mango'}), conf: 1.0
# frozenset({'Mango'}) ---> frozenset({'Onion', 'Key-chain'}), conf: 1.0
# frozenset({'Onion'}) ---> frozenset({'Mango', 'Key-chain'}), conf: 1.0
# frozenset({'Eggs'}) ---> frozenset({'Onion', 'Mango'}), conf: 1.0
# frozenset({'Mango'}) ---> frozenset({'Onion', 'Eggs'}), conf: 1.0
# frozenset({'Onion'}) ---> frozenset({'Mango', 'Eggs'}), conf: 1.0
# frozenset({'Yo-yo'}) ---> frozenset({'Onion', 'Mango'}), conf: 1.0
# frozenset({'Mango'}) ---> frozenset({'Onion', 'Yo-yo'}), conf: 1.0
# frozenset({'Onion'}) ---> frozenset({'Mango', 'Yo-yo'}), conf: 1.0
# frozenset({'Key-chain'}) ---> frozenset({'Nintendo', 'Mango'}), conf: 1.0
# frozenset({'Mango'}) ---> frozenset({'Nintendo', 'Key-chain'}), conf: 1.0
# frozenset({'Nintendo'}) ---> frozenset({'Mango', 'Key-chain'}), conf: 1.0
# frozenset({'Eggs'}) ---> frozenset({'Nintendo', 'Mango'}), conf: 1.0
# frozenset({'Mango'}) ---> frozenset({'Nintendo', 'Eggs'}), conf: 1.0
# frozenset({'Nintendo'}) ---> frozenset({'Mango', 'Eggs'}), conf: 1.0
# frozenset({'Yo-yo'}) ---> frozenset({'Nintendo', 'Mango'}), conf: 1.0
# frozenset({'Mango'}) ---> frozenset({'Nintendo', 'Yo-yo'}), conf: 1.0
# frozenset({'Nintendo'}) ---> frozenset({'Mango', 'Yo-yo'}), conf: 1.0
# frozenset({'Key-chain'}) ---> frozenset({'Mango', 'Eggs'}), conf: 2.0
# frozenset({'Mango'}) ---> frozenset({'Key-chain', 'Eggs'}), conf: 2.0
# frozenset({'Eggs'}) ---> frozenset({'Mango', 'Key-chain'}), conf: 2.0
# frozenset({'Yo-yo'}) ---> frozenset({'Mango', 'Key-chain'}), conf: 2.0
# frozenset({'Key-chain'}) ---> frozenset({'Mango', 'Yo-yo'}), conf: 2.0
# frozenset({'Mango'}) ---> frozenset({'Key-chain', 'Yo-yo'}), conf: 2.0
# frozenset({'Yo-yo'}) ---> frozenset({'Mango', 'Eggs'}), conf: 1.0
# frozenset({'Eggs'}) ---> frozenset({'Mango', 'Yo-yo'}), conf: 1.0
# frozenset({'Mango'}) ---> frozenset({'Eggs', 'Yo-yo'}), conf: 1.0
# frozenset({'Key-chain'}) ---> frozenset({'Onion', 'Nintendo'}), conf: 2.0
# frozenset({'Nintendo'}) ---> frozenset({'Onion', 'Key-chain'}), conf: 2.0
# frozenset({'Onion'}) ---> frozenset({'Nintendo', 'Key-chain'}), conf: 2.0
# frozenset({'Eggs'}) ---> frozenset({'Onion', 'Nintendo'}), conf: 2.0
# frozenset({'Nintendo'}) ---> frozenset({'Onion', 'Eggs'}), conf: 2.0
# frozenset({'Onion'}) ---> frozenset({'Nintendo', 'Eggs'}), conf: 2.0
# frozenset({'Yo-yo'}) ---> frozenset({'Onion', 'Nintendo'}), conf: 2.0
# frozenset({'Nintendo'}) ---> frozenset({'Onion', 'Yo-yo'}), conf: 2.0
# frozenset({'Onion'}) ---> frozenset({'Nintendo', 'Yo-yo'}), conf: 2.0
# frozenset({'Key-chain'}) ---> frozenset({'Onion', 'Eggs'}), conf: 2.9999999999999996
# frozenset({'Eggs'}) ---> frozenset({'Onion', 'Key-chain'}), conf: 2.9999999999999996
# frozenset({'Onion'}) ---> frozenset({'Key-chain', 'Eggs'}), conf: 2.9999999999999996
# frozenset({'Yo-yo'}) ---> frozenset({'Onion', 'Key-chain'}), conf: 2.0
# frozenset({'Key-chain'}) ---> frozenset({'Onion', 'Yo-yo'}), conf: 2.0
# frozenset({'Onion'}) ---> frozenset({'Key-chain', 'Yo-yo'}), conf: 2.0
# frozenset({'Yo-yo'}) ---> frozenset({'Onion', 'Eggs'}), conf: 2.0
# frozenset({'Eggs'}) ---> frozenset({'Onion', 'Yo-yo'}), conf: 2.0
# frozenset({'Onion'}) ---> frozenset({'Eggs', 'Yo-yo'}), conf: 2.0
# frozenset({'Key-chain'}) ---> frozenset({'Nintendo', 'Eggs'}), conf: 2.0
# frozenset({'Nintendo'}) ---> frozenset({'Key-chain', 'Eggs'}), conf: 2.0
# frozenset({'Eggs'}) ---> frozenset({'Nintendo', 'Key-chain'}), conf: 2.0
# frozenset({'Yo-yo'}) ---> frozenset({'Nintendo', 'Key-chain'}), conf: 2.0
# frozenset({'Key-chain'}) ---> frozenset({'Nintendo', 'Yo-yo'}), conf: 2.0
# frozenset({'Nintendo'}) ---> frozenset({'Key-chain', 'Yo-yo'}), conf: 2.0
# frozenset({'Yo-yo'}) ---> frozenset({'Nintendo', 'Eggs'}), conf: 2.0
# frozenset({'Eggs'}) ---> frozenset({'Nintendo', 'Yo-yo'}), conf: 2.0
# frozenset({'Nintendo'}) ---> frozenset({'Eggs', 'Yo-yo'}), conf: 2.0
# frozenset({'Yo-yo'}) ---> frozenset({'Key-chain', 'Eggs'}), conf: 2.0
# frozenset({'Key-chain'}) ---> frozenset({'Eggs', 'Yo-yo'}), conf: 2.0
# frozenset({'Eggs'}) ---> frozenset({'Key-chain', 'Yo-yo'}), conf: 2.0
# frozenset({'Nintendo', 'Mango'}) ---> frozenset({'Onion', 'Key-chain'}), conf: 1.0
# frozenset({'Onion', 'Mango'}) ---> frozenset({'Nintendo', 'Key-chain'}), conf: 1.0
# frozenset({'Nintendo', 'Mango'}) ---> frozenset({'Onion', 'Eggs'}), conf: 1.0
# frozenset({'Onion', 'Mango'}) ---> frozenset({'Nintendo', 'Eggs'}), conf: 1.0
# frozenset({'Nintendo', 'Mango'}) ---> frozenset({'Onion', 'Yo-yo'}), conf: 1.0
# frozenset({'Onion', 'Mango'}) ---> frozenset({'Nintendo', 'Yo-yo'}), conf: 1.0
# frozenset({'Onion', 'Mango'}) ---> frozenset({'Eggs', 'Key-chain'}), conf: 1.0
# frozenset({'Onion', 'Mango'}) ---> frozenset({'Key-chain', 'Yo-yo'}), conf: 1.0
# frozenset({'Onion', 'Mango'}) ---> frozenset({'Eggs', 'Yo-yo'}), conf: 1.0
# frozenset({'Nintendo', 'Mango'}) ---> frozenset({'Eggs', 'Key-chain'}), conf: 1.0
# frozenset({'Nintendo', 'Mango'}) ---> frozenset({'Key-chain', 'Yo-yo'}), conf: 1.0
# frozenset({'Nintendo', 'Mango'}) ---> frozenset({'Eggs', 'Yo-yo'}), conf: 1.0
# frozenset({'Nintendo', 'Eggs'}) ---> frozenset({'Onion', 'Key-chain'}), conf: 1.0
# frozenset({'Nintendo', 'Key-chain'}) ---> frozenset({'Onion', 'Eggs'}), conf: 1.0
# frozenset({'Onion', 'Nintendo'}) ---> frozenset({'Eggs', 'Key-chain'}), conf: 1.0
# frozenset({'Nintendo'}) ---> frozenset({'Onion', 'Eggs', 'Key-chain'}), conf: 2.0
# frozenset({'Nintendo', 'Yo-yo'}) ---> frozenset({'Onion', 'Key-chain'}), conf: 1.0
# frozenset({'Nintendo', 'Key-chain'}) ---> frozenset({'Onion', 'Yo-yo'}), conf: 1.0
# frozenset({'Onion', 'Yo-yo'}) ---> frozenset({'Nintendo', 'Key-chain'}), conf: 1.0
# frozenset({'Onion', 'Nintendo'}) ---> frozenset({'Key-chain', 'Yo-yo'}), conf: 1.0
# frozenset({'Nintendo'}) ---> frozenset({'Onion', 'Key-chain', 'Yo-yo'}), conf: 2.0
# frozenset({'Nintendo', 'Yo-yo'}) ---> frozenset({'Onion', 'Eggs'}), conf: 1.0
# frozenset({'Eggs', 'Yo-yo'}) ---> frozenset({'Onion', 'Nintendo'}), conf: 1.0
# frozenset({'Nintendo', 'Eggs'}) ---> frozenset({'Onion', 'Yo-yo'}), conf: 1.0
# frozenset({'Onion', 'Yo-yo'}) ---> frozenset({'Nintendo', 'Eggs'}), conf: 1.0
# frozenset({'Onion', 'Nintendo'}) ---> frozenset({'Eggs', 'Yo-yo'}), conf: 1.0
# frozenset({'Yo-yo'}) ---> frozenset({'Onion', 'Nintendo', 'Eggs'}), conf: 2.0
# frozenset({'Nintendo'}) ---> frozenset({'Onion', 'Eggs', 'Yo-yo'}), conf: 2.0
# frozenset({'Eggs'}) ---> frozenset({'Onion', 'Nintendo', 'Yo-yo'}), conf: 2.0
# frozenset({'Eggs', 'Yo-yo'}) ---> frozenset({'Onion', 'Key-chain'}), conf: 1.0
# frozenset({'Onion', 'Yo-yo'}) ---> frozenset({'Key-chain', 'Eggs'}), conf: 1.0
# frozenset({'Nintendo', 'Yo-yo'}) ---> frozenset({'Key-chain', 'Eggs'}), conf: 1.0
# frozenset({'Nintendo', 'Key-chain'}) ---> frozenset({'Eggs', 'Yo-yo'}), conf: 1.0
# frozenset({'Eggs', 'Yo-yo'}) ---> frozenset({'Nintendo', 'Key-chain'}), conf: 1.0
# frozenset({'Nintendo', 'Eggs'}) ---> frozenset({'Key-chain', 'Yo-yo'}), conf: 1.0
# frozenset({'Nintendo'}) ---> frozenset({'Key-chain', 'Eggs', 'Yo-yo'}), conf: 2.0
# frozenset({'Onion', 'Mango', 'Eggs'}) ---> frozenset({'Nintendo', 'Key-chain'}), conf: 1.0
# frozenset({'Onion', 'Mango', 'Key-chain'}) ---> frozenset({'Nintendo', 'Eggs'}), conf: 1.0
# frozenset({'Nintendo', 'Mango', 'Eggs'}) ---> frozenset({'Onion', 'Key-chain'}), conf: 1.0
# frozenset({'Nintendo', 'Mango', 'Key-chain'}) ---> frozenset({'Onion', 'Eggs'}), conf: 1.0
# frozenset({'Nintendo', 'Onion', 'Mango'}) ---> frozenset({'Eggs', 'Key-chain'}), conf: 1.0
# frozenset({'Onion', 'Mango'}) ---> frozenset({'Eggs', 'Nintendo', 'Key-chain'}), conf: 1.0
# frozenset({'Nintendo', 'Mango'}) ---> frozenset({'Onion', 'Eggs', 'Key-chain'}), conf: 1.0
# frozenset({'Onion', 'Mango', 'Yo-yo'}) ---> frozenset({'Nintendo', 'Key-chain'}), conf: 1.0
# frozenset({'Onion', 'Mango', 'Key-chain'}) ---> frozenset({'Nintendo', 'Yo-yo'}), conf: 1.0
# frozenset({'Nintendo', 'Mango', 'Yo-yo'}) ---> frozenset({'Onion', 'Key-chain'}), conf: 1.0
# frozenset({'Nintendo', 'Mango', 'Key-chain'}) ---> frozenset({'Onion', 'Yo-yo'}), conf: 1.0
# frozenset({'Nintendo', 'Onion', 'Mango'}) ---> frozenset({'Key-chain', 'Yo-yo'}), conf: 1.0
# frozenset({'Onion', 'Mango'}) ---> frozenset({'Nintendo', 'Key-chain', 'Yo-yo'}), conf: 1.0
# frozenset({'Nintendo', 'Mango'}) ---> frozenset({'Onion', 'Key-chain', 'Yo-yo'}), conf: 1.0
# frozenset({'Mango', 'Eggs', 'Yo-yo'}) ---> frozenset({'Onion', 'Nintendo'}), conf: 1.0
# frozenset({'Onion', 'Mango', 'Yo-yo'}) ---> frozenset({'Nintendo', 'Eggs'}), conf: 1.0
# frozenset({'Onion', 'Mango', 'Eggs'}) ---> frozenset({'Nintendo', 'Yo-yo'}), conf: 1.0
# frozenset({'Nintendo', 'Mango', 'Yo-yo'}) ---> frozenset({'Onion', 'Eggs'}), conf: 1.0
# frozenset({'Nintendo', 'Mango', 'Eggs'}) ---> frozenset({'Onion', 'Yo-yo'}), conf: 1.0
# frozenset({'Nintendo', 'Onion', 'Mango'}) ---> frozenset({'Eggs', 'Yo-yo'}), conf: 1.0
# frozenset({'Onion', 'Mango'}) ---> frozenset({'Nintendo', 'Eggs', 'Yo-yo'}), conf: 1.0
# frozenset({'Nintendo', 'Mango'}) ---> frozenset({'Onion', 'Eggs', 'Yo-yo'}), conf: 1.0
# frozenset({'Mango', 'Eggs', 'Yo-yo'}) ---> frozenset({'Onion', 'Key-chain'}), conf: 1.0
# frozenset({'Onion', 'Mango', 'Yo-yo'}) ---> frozenset({'Key-chain', 'Eggs'}), conf: 1.0
# frozenset({'Onion', 'Mango', 'Key-chain'}) ---> frozenset({'Eggs', 'Yo-yo'}), conf: 1.0
# frozenset({'Onion', 'Mango', 'Eggs'}) ---> frozenset({'Key-chain', 'Yo-yo'}), conf: 1.0
# frozenset({'Onion', 'Mango'}) ---> frozenset({'Key-chain', 'Eggs', 'Yo-yo'}), conf: 1.0
# frozenset({'Mango', 'Eggs', 'Yo-yo'}) ---> frozenset({'Nintendo', 'Key-chain'}), conf: 1.0
# frozenset({'Nintendo', 'Mango', 'Yo-yo'}) ---> frozenset({'Key-chain', 'Eggs'}), conf: 1.0
# frozenset({'Nintendo', 'Mango', 'Key-chain'}) ---> frozenset({'Eggs', 'Yo-yo'}), conf: 1.0
# frozenset({'Nintendo', 'Mango', 'Eggs'}) ---> frozenset({'Key-chain', 'Yo-yo'}), conf: 1.0
# frozenset({'Nintendo', 'Mango'}) ---> frozenset({'Key-chain', 'Eggs', 'Yo-yo'}), conf: 1.0
# frozenset({'Key-chain', 'Eggs', 'Yo-yo'}) ---> frozenset({'Onion', 'Nintendo'}), conf: 1.0
# frozenset({'Onion', 'Key-chain', 'Yo-yo'}) ---> frozenset({'Nintendo', 'Eggs'}), conf: 1.0
# frozenset({'Onion', 'Eggs', 'Yo-yo'}) ---> frozenset({'Nintendo', 'Key-chain'}), conf: 1.0
# frozenset({'Nintendo', 'Key-chain', 'Yo-yo'}) ---> frozenset({'Onion', 'Eggs'}), conf: 1.0
# frozenset({'Nintendo', 'Eggs', 'Yo-yo'}) ---> frozenset({'Onion', 'Key-chain'}), conf: 1.0
# frozenset({'Key-chain', 'Nintendo', 'Eggs'}) ---> frozenset({'Onion', 'Yo-yo'}), conf: 1.0
# frozenset({'Onion', 'Nintendo', 'Yo-yo'}) ---> frozenset({'Key-chain', 'Eggs'}), conf: 1.0
# frozenset({'Onion', 'Nintendo', 'Key-chain'}) ---> frozenset({'Eggs', 'Yo-yo'}), conf: 1.0
# frozenset({'Onion', 'Nintendo', 'Eggs'}) ---> frozenset({'Key-chain', 'Yo-yo'}), conf: 1.0
# frozenset({'Eggs', 'Yo-yo'}) ---> frozenset({'Onion', 'Nintendo', 'Key-chain'}), conf: 1.0
# frozenset({'Onion', 'Yo-yo'}) ---> frozenset({'Key-chain', 'Nintendo', 'Eggs'}), conf: 1.0
# frozenset({'Nintendo', 'Yo-yo'}) ---> frozenset({'Onion', 'Key-chain', 'Eggs'}), conf: 1.0
# frozenset({'Nintendo', 'Key-chain'}) ---> frozenset({'Onion', 'Eggs', 'Yo-yo'}), conf: 1.0
# frozenset({'Nintendo', 'Eggs'}) ---> frozenset({'Onion', 'Key-chain', 'Yo-yo'}), conf: 1.0
# frozenset({'Onion', 'Nintendo'}) ---> frozenset({'Key-chain', 'Eggs', 'Yo-yo'}), conf: 1.0
# frozenset({'Nintendo'}) ---> frozenset({'Onion', 'Key-chain', 'Eggs', 'Yo-yo'}), conf: 2.0
# frozenset({'Eggs', 'Mango', 'Key-chain', 'Yo-yo'}) ---> frozenset({'Onion', 'Nintendo'}), conf: 1.0
# frozenset({'Onion', 'Mango', 'Eggs', 'Yo-yo'}) ---> frozenset({'Nintendo', 'Key-chain'}), conf: 1.0
# frozenset({'Onion', 'Mango', 'Key-chain', 'Yo-yo'}) ---> frozenset({'Nintendo', 'Eggs'}), conf: 1.0
# frozenset({'Onion', 'Mango', 'Eggs', 'Key-chain'}) ---> frozenset({'Nintendo', 'Yo-yo'}), conf: 1.0
# frozenset({'Nintendo', 'Mango', 'Eggs', 'Yo-yo'}) ---> frozenset({'Onion', 'Key-chain'}), conf: 1.0
# frozenset({'Nintendo', 'Mango', 'Key-chain', 'Yo-yo'}) ---> frozenset({'Onion', 'Eggs'}), conf: 1.0
# frozenset({'Nintendo', 'Eggs', 'Mango', 'Key-chain'}) ---> frozenset({'Onion', 'Yo-yo'}), conf: 1.0
# frozenset({'Nintendo', 'Onion', 'Mango', 'Yo-yo'}) ---> frozenset({'Eggs', 'Key-chain'}), conf: 1.0
# frozenset({'Nintendo', 'Onion', 'Mango', 'Eggs'}) ---> frozenset({'Key-chain', 'Yo-yo'}), conf: 1.0
# frozenset({'Nintendo', 'Onion', 'Mango', 'Key-chain'}) ---> frozenset({'Eggs', 'Yo-yo'}), conf: 1.0
# frozenset({'Mango', 'Eggs', 'Yo-yo'}) ---> frozenset({'Onion', 'Nintendo', 'Key-chain'}), conf: 1.0
# frozenset({'Onion', 'Mango', 'Yo-yo'}) ---> frozenset({'Eggs', 'Nintendo', 'Key-chain'}), conf: 1.0
# frozenset({'Onion', 'Mango', 'Eggs'}) ---> frozenset({'Nintendo', 'Key-chain', 'Yo-yo'}), conf: 1.0
# frozenset({'Onion', 'Mango', 'Key-chain'}) ---> frozenset({'Nintendo', 'Eggs', 'Yo-yo'}), conf: 1.0
# frozenset({'Nintendo', 'Mango', 'Yo-yo'}) ---> frozenset({'Onion', 'Eggs', 'Key-chain'}), conf: 1.0
# frozenset({'Nintendo', 'Mango', 'Eggs'}) ---> frozenset({'Onion', 'Key-chain', 'Yo-yo'}), conf: 1.0
# frozenset({'Nintendo', 'Mango', 'Key-chain'}) ---> frozenset({'Onion', 'Eggs', 'Yo-yo'}), conf: 1.0
# frozenset({'Nintendo', 'Onion', 'Mango'}) ---> frozenset({'Eggs', 'Key-chain', 'Yo-yo'}), conf: 1.0
# frozenset({'Onion', 'Mango'}) ---> frozenset({'Eggs', 'Key-chain', 'Nintendo', 'Yo-yo'}), conf: 1.0
# frozenset({'Nintendo', 'Mango'}) ---> frozenset({'Onion', 'Eggs', 'Key-chain', 'Yo-yo'}), conf: 1.0
# [(frozenset({'Mango'}), frozenset({'Onion'}), 1.0),
#  (frozenset({'Onion'}), frozenset({'Mango'}), 1.0),
#  (frozenset({'Mango'}), frozenset({'Nintendo'}), 1.0),
#  (frozenset({'Nintendo'}), frozenset({'Mango'}), 1.0),
#  (frozenset({'Key-chain'}), frozenset({'Mango'}), 2.9999999999999996),
#  (frozenset({'Mango'}), frozenset({'Key-chain'}), 2.9999999999999996),
#  (frozenset({'Eggs'}), frozenset({'Mango'}), 2.0),
#  (frozenset({'Mango'}), frozenset({'Eggs'}), 2.0),
#  (frozenset({'Yo-yo'}), frozenset({'Mango'}), 2.0),
#  (frozenset({'Mango'}), frozenset({'Yo-yo'}), 2.0),
#  (frozenset({'Nintendo'}), frozenset({'Onion'}), 2.0),
#  (frozenset({'Onion'}), frozenset({'Nintendo'}), 2.0),
#  (frozenset({'Key-chain'}), frozenset({'Onion'}), 2.9999999999999996),
#  (frozenset({'Onion'}), frozenset({'Key-chain'}), 2.9999999999999996),
#  (frozenset({'Eggs'}), frozenset({'Onion'}), 2.9999999999999996),
#  (frozenset({'Onion'}), frozenset({'Eggs'}), 2.9999999999999996),
#  (frozenset({'Yo-yo'}), frozenset({'Onion'}), 2.0),
#  (frozenset({'Onion'}), frozenset({'Yo-yo'}), 2.0),
#  (frozenset({'Key-chain'}), frozenset({'Nintendo'}), 2.0),
#  (frozenset({'Nintendo'}), frozenset({'Key-chain'}), 2.0),
#  (frozenset({'Eggs'}), frozenset({'Nintendo'}), 2.0),
#  (frozenset({'Nintendo'}), frozenset({'Eggs'}), 2.0),
#  (frozenset({'Yo-yo'}), frozenset({'Nintendo'}), 2.0),
#  (frozenset({'Nintendo'}), frozenset({'Yo-yo'}), 2.0),
#  (frozenset({'Key-chain'}), frozenset({'Eggs'}), 4.0),
#  (frozenset({'Eggs'}), frozenset({'Key-chain'}), 4.0),
#  (frozenset({'Yo-yo'}), frozenset({'Key-chain'}), 2.9999999999999996),
#  (frozenset({'Key-chain'}), frozenset({'Yo-yo'}), 2.9999999999999996),
#  (frozenset({'Yo-yo'}), frozenset({'Eggs'}), 2.0),
#  (frozenset({'Eggs'}), frozenset({'Yo-yo'}), 2.0),
#  (frozenset({'Mango'}), frozenset({'Nintendo', 'Onion'}), 1.0),
#  (frozenset({'Onion'}), frozenset({'Mango', 'Nintendo'}), 1.0),
#  (frozenset({'Nintendo'}), frozenset({'Mango', 'Onion'}), 1.0),
#  (frozenset({'Key-chain'}), frozenset({'Mango', 'Onion'}), 1.0),
#  (frozenset({'Mango'}), frozenset({'Key-chain', 'Onion'}), 1.0),
#  (frozenset({'Onion'}), frozenset({'Key-chain', 'Mango'}), 1.0),
#  (frozenset({'Eggs'}), frozenset({'Mango', 'Onion'}), 1.0),
#  (frozenset({'Mango'}), frozenset({'Eggs', 'Onion'}), 1.0),
#  (frozenset({'Onion'}), frozenset({'Eggs', 'Mango'}), 1.0),
#  (frozenset({'Yo-yo'}), frozenset({'Mango', 'Onion'}), 1.0),
#  (frozenset({'Mango'}), frozenset({'Onion', 'Yo-yo'}), 1.0),
#  (frozenset({'Onion'}), frozenset({'Mango', 'Yo-yo'}), 1.0),
#  (frozenset({'Key-chain'}), frozenset({'Mango', 'Nintendo'}), 1.0),
#  (frozenset({'Mango'}), frozenset({'Key-chain', 'Nintendo'}), 1.0),
#  (frozenset({'Nintendo'}), frozenset({'Key-chain', 'Mango'}), 1.0),
#  (frozenset({'Eggs'}), frozenset({'Mango', 'Nintendo'}), 1.0),
#  (frozenset({'Mango'}), frozenset({'Eggs', 'Nintendo'}), 1.0),
#  (frozenset({'Nintendo'}), frozenset({'Eggs', 'Mango'}), 1.0),
#  (frozenset({'Yo-yo'}), frozenset({'Mango', 'Nintendo'}), 1.0),
#  (frozenset({'Mango'}), frozenset({'Nintendo', 'Yo-yo'}), 1.0),
#  (frozenset({'Nintendo'}), frozenset({'Mango', 'Yo-yo'}), 1.0),
#  (frozenset({'Key-chain'}), frozenset({'Eggs', 'Mango'}), 2.0),
#  (frozenset({'Mango'}), frozenset({'Eggs', 'Key-chain'}), 2.0),
#  (frozenset({'Eggs'}), frozenset({'Key-chain', 'Mango'}), 2.0),
#  (frozenset({'Yo-yo'}), frozenset({'Key-chain', 'Mango'}), 2.0),
#  (frozenset({'Key-chain'}), frozenset({'Mango', 'Yo-yo'}), 2.0),
#  (frozenset({'Mango'}), frozenset({'Key-chain', 'Yo-yo'}), 2.0),
#  (frozenset({'Yo-yo'}), frozenset({'Eggs', 'Mango'}), 1.0),
#  (frozenset({'Eggs'}), frozenset({'Mango', 'Yo-yo'}), 1.0),
#  (frozenset({'Mango'}), frozenset({'Eggs', 'Yo-yo'}), 1.0),
#  (frozenset({'Key-chain'}), frozenset({'Nintendo', 'Onion'}), 2.0),
#  (frozenset({'Nintendo'}), frozenset({'Key-chain', 'Onion'}), 2.0),
#  (frozenset({'Onion'}), frozenset({'Key-chain', 'Nintendo'}), 2.0),
#  (frozenset({'Eggs'}), frozenset({'Nintendo', 'Onion'}), 2.0),
#  (frozenset({'Nintendo'}), frozenset({'Eggs', 'Onion'}), 2.0),
#  (frozenset({'Onion'}), frozenset({'Eggs', 'Nintendo'}), 2.0),
#  (frozenset({'Yo-yo'}), frozenset({'Nintendo', 'Onion'}), 2.0),
#  (frozenset({'Nintendo'}), frozenset({'Onion', 'Yo-yo'}), 2.0),
#  (frozenset({'Onion'}), frozenset({'Nintendo', 'Yo-yo'}), 2.0),
#  (frozenset({'Key-chain'}), frozenset({'Eggs', 'Onion'}), 2.9999999999999996),
#  (frozenset({'Eggs'}), frozenset({'Key-chain', 'Onion'}), 2.9999999999999996),
#  (frozenset({'Onion'}), frozenset({'Eggs', 'Key-chain'}), 2.9999999999999996),
#  (frozenset({'Yo-yo'}), frozenset({'Key-chain', 'Onion'}), 2.0),
#  (frozenset({'Key-chain'}), frozenset({'Onion', 'Yo-yo'}), 2.0),
#  (frozenset({'Onion'}), frozenset({'Key-chain', 'Yo-yo'}), 2.0),
#  (frozenset({'Yo-yo'}), frozenset({'Eggs', 'Onion'}), 2.0),
#  (frozenset({'Eggs'}), frozenset({'Onion', 'Yo-yo'}), 2.0),
#  (frozenset({'Onion'}), frozenset({'Eggs', 'Yo-yo'}), 2.0),
#  (frozenset({'Key-chain'}), frozenset({'Eggs', 'Nintendo'}), 2.0),
#  (frozenset({'Nintendo'}), frozenset({'Eggs', 'Key-chain'}), 2.0),
#  (frozenset({'Eggs'}), frozenset({'Key-chain', 'Nintendo'}), 2.0),
#  (frozenset({'Yo-yo'}), frozenset({'Key-chain', 'Nintendo'}), 2.0),
#  (frozenset({'Key-chain'}), frozenset({'Nintendo', 'Yo-yo'}), 2.0),
#  (frozenset({'Nintendo'}), frozenset({'Key-chain', 'Yo-yo'}), 2.0),
#  (frozenset({'Yo-yo'}), frozenset({'Eggs', 'Nintendo'}), 2.0),
#  (frozenset({'Eggs'}), frozenset({'Nintendo', 'Yo-yo'}), 2.0),
#  (frozenset({'Nintendo'}), frozenset({'Eggs', 'Yo-yo'}), 2.0),
#  (frozenset({'Yo-yo'}), frozenset({'Eggs', 'Key-chain'}), 2.0),
#  (frozenset({'Key-chain'}), frozenset({'Eggs', 'Yo-yo'}), 2.0),
#  (frozenset({'Eggs'}), frozenset({'Key-chain', 'Yo-yo'}), 2.0),
#  (frozenset({'Mango', 'Nintendo'}), frozenset({'Key-chain', 'Onion'}), 1.0),
#  (frozenset({'Mango', 'Onion'}), frozenset({'Key-chain', 'Nintendo'}), 1.0),
#  (frozenset({'Mango', 'Nintendo'}), frozenset({'Eggs', 'Onion'}), 1.0),
#  (frozenset({'Mango', 'Onion'}), frozenset({'Eggs', 'Nintendo'}), 1.0),
#  (frozenset({'Mango', 'Nintendo'}), frozenset({'Onion', 'Yo-yo'}), 1.0),
#  (frozenset({'Mango', 'Onion'}), frozenset({'Nintendo', 'Yo-yo'}), 1.0),
#  (frozenset({'Mango', 'Onion'}), frozenset({'Eggs', 'Key-chain'}), 1.0),
#  (frozenset({'Mango', 'Onion'}), frozenset({'Key-chain', 'Yo-yo'}), 1.0),
#  (frozenset({'Mango', 'Onion'}), frozenset({'Eggs', 'Yo-yo'}), 1.0),
#  (frozenset({'Mango', 'Nintendo'}), frozenset({'Eggs', 'Key-chain'}), 1.0),
#  (frozenset({'Mango', 'Nintendo'}), frozenset({'Key-chain', 'Yo-yo'}), 1.0),
#  (frozenset({'Mango', 'Nintendo'}), frozenset({'Eggs', 'Yo-yo'}), 1.0),
#  (frozenset({'Eggs', 'Nintendo'}), frozenset({'Key-chain', 'Onion'}), 1.0),
#  (frozenset({'Key-chain', 'Nintendo'}), frozenset({'Eggs', 'Onion'}), 1.0),
#  (frozenset({'Nintendo', 'Onion'}), frozenset({'Eggs', 'Key-chain'}), 1.0),
#  (frozenset({'Nintendo'}), frozenset({'Eggs', 'Key-chain', 'Onion'}), 2.0),
#  (frozenset({'Nintendo', 'Yo-yo'}), frozenset({'Key-chain', 'Onion'}), 1.0),
#  (frozenset({'Key-chain', 'Nintendo'}), frozenset({'Onion', 'Yo-yo'}), 1.0),
#  (frozenset({'Onion', 'Yo-yo'}), frozenset({'Key-chain', 'Nintendo'}), 1.0),
#  (frozenset({'Nintendo', 'Onion'}), frozenset({'Key-chain', 'Yo-yo'}), 1.0),
#  (frozenset({'Nintendo'}), frozenset({'Key-chain', 'Onion', 'Yo-yo'}), 2.0),
#  (frozenset({'Nintendo', 'Yo-yo'}), frozenset({'Eggs', 'Onion'}), 1.0),
#  (frozenset({'Eggs', 'Yo-yo'}), frozenset({'Nintendo', 'Onion'}), 1.0),
#  (frozenset({'Eggs', 'Nintendo'}), frozenset({'Onion', 'Yo-yo'}), 1.0),
#  (frozenset({'Onion', 'Yo-yo'}), frozenset({'Eggs', 'Nintendo'}), 1.0),
#  (frozenset({'Nintendo', 'Onion'}), frozenset({'Eggs', 'Yo-yo'}), 1.0),
#  (frozenset({'Yo-yo'}), frozenset({'Eggs', 'Nintendo', 'Onion'}), 2.0),
#  (frozenset({'Nintendo'}), frozenset({'Eggs', 'Onion', 'Yo-yo'}), 2.0),
#  (frozenset({'Eggs'}), frozenset({'Nintendo', 'Onion', 'Yo-yo'}), 2.0),
#  (frozenset({'Eggs', 'Yo-yo'}), frozenset({'Key-chain', 'Onion'}), 1.0),
#  (frozenset({'Onion', 'Yo-yo'}), frozenset({'Eggs', 'Key-chain'}), 1.0),
#  (frozenset({'Nintendo', 'Yo-yo'}), frozenset({'Eggs', 'Key-chain'}), 1.0),
#  (frozenset({'Key-chain', 'Nintendo'}), frozenset({'Eggs', 'Yo-yo'}), 1.0),
#  (frozenset({'Eggs', 'Yo-yo'}), frozenset({'Key-chain', 'Nintendo'}), 1.0),
#  (frozenset({'Eggs', 'Nintendo'}), frozenset({'Key-chain', 'Yo-yo'}), 1.0),
#  (frozenset({'Nintendo'}), frozenset({'Eggs', 'Key-chain', 'Yo-yo'}), 2.0),
#  (frozenset({'Eggs', 'Mango', 'Onion'}),
#   frozenset({'Key-chain', 'Nintendo'}),
#   1.0),
#  (frozenset({'Key-chain', 'Mango', 'Onion'}),
#   frozenset({'Eggs', 'Nintendo'}),
#   1.0),
#  (frozenset({'Eggs', 'Mango', 'Nintendo'}),
#   frozenset({'Key-chain', 'Onion'}),
#   1.0),
#  (frozenset({'Key-chain', 'Mango', 'Nintendo'}),
#   frozenset({'Eggs', 'Onion'}),
#   1.0),
#  (frozenset({'Mango', 'Nintendo', 'Onion'}),
#   frozenset({'Eggs', 'Key-chain'}),
#   1.0),
#  (frozenset({'Mango', 'Onion'}),
#   frozenset({'Eggs', 'Key-chain', 'Nintendo'}),
#   1.0),
#  (frozenset({'Mango', 'Nintendo'}),
#   frozenset({'Eggs', 'Key-chain', 'Onion'}),
#   1.0),
#  (frozenset({'Mango', 'Onion', 'Yo-yo'}),
#   frozenset({'Key-chain', 'Nintendo'}),
#   1.0),
#  (frozenset({'Key-chain', 'Mango', 'Onion'}),
#   frozenset({'Nintendo', 'Yo-yo'}),
#   1.0),
#  (frozenset({'Mango', 'Nintendo', 'Yo-yo'}),
#   frozenset({'Key-chain', 'Onion'}),
#   1.0),
#  (frozenset({'Key-chain', 'Mango', 'Nintendo'}),
#   frozenset({'Onion', 'Yo-yo'}),
#   1.0),
#  (frozenset({'Mango', 'Nintendo', 'Onion'}),
#   frozenset({'Key-chain', 'Yo-yo'}),
#   1.0),
#  (frozenset({'Mango', 'Onion'}),
#   frozenset({'Key-chain', 'Nintendo', 'Yo-yo'}),
#   1.0),
#  (frozenset({'Mango', 'Nintendo'}),
#   frozenset({'Key-chain', 'Onion', 'Yo-yo'}),
#   1.0),
#  (frozenset({'Eggs', 'Mango', 'Yo-yo'}),
#   frozenset({'Nintendo', 'Onion'}),
#   1.0),
#  (frozenset({'Mango', 'Onion', 'Yo-yo'}),
#   frozenset({'Eggs', 'Nintendo'}),
#   1.0),
#  (frozenset({'Eggs', 'Mango', 'Onion'}),
#   frozenset({'Nintendo', 'Yo-yo'}),
#   1.0),
#  (frozenset({'Mango', 'Nintendo', 'Yo-yo'}),
#   frozenset({'Eggs', 'Onion'}),
#   1.0),
#  (frozenset({'Eggs', 'Mango', 'Nintendo'}),
#   frozenset({'Onion', 'Yo-yo'}),
#   1.0),
#  (frozenset({'Mango', 'Nintendo', 'Onion'}),
#   frozenset({'Eggs', 'Yo-yo'}),
#   1.0),
#  (frozenset({'Mango', 'Onion'}),
#   frozenset({'Eggs', 'Nintendo', 'Yo-yo'}),
#   1.0),
#  (frozenset({'Mango', 'Nintendo'}),
#   frozenset({'Eggs', 'Onion', 'Yo-yo'}),
#   1.0),
#  (frozenset({'Eggs', 'Mango', 'Yo-yo'}),
#   frozenset({'Key-chain', 'Onion'}),
#   1.0),
#  (frozenset({'Mango', 'Onion', 'Yo-yo'}),
#   frozenset({'Eggs', 'Key-chain'}),
#   1.0),
#  (frozenset({'Key-chain', 'Mango', 'Onion'}),
#   frozenset({'Eggs', 'Yo-yo'}),
#   1.0),
#  (frozenset({'Eggs', 'Mango', 'Onion'}),
#   frozenset({'Key-chain', 'Yo-yo'}),
#   1.0),
#  (frozenset({'Mango', 'Onion'}),
#   frozenset({'Eggs', 'Key-chain', 'Yo-yo'}),
#   1.0),
#  (frozenset({'Eggs', 'Mango', 'Yo-yo'}),
#   frozenset({'Key-chain', 'Nintendo'}),
#   1.0),
#  (frozenset({'Mango', 'Nintendo', 'Yo-yo'}),
#   frozenset({'Eggs', 'Key-chain'}),
#   1.0),
#  (frozenset({'Key-chain', 'Mango', 'Nintendo'}),
#   frozenset({'Eggs', 'Yo-yo'}),
#   1.0),
#  (frozenset({'Eggs', 'Mango', 'Nintendo'}),
#   frozenset({'Key-chain', 'Yo-yo'}),
#   1.0),
#  (frozenset({'Mango', 'Nintendo'}),
#   frozenset({'Eggs', 'Key-chain', 'Yo-yo'}),
#   1.0),
#  (frozenset({'Eggs', 'Key-chain', 'Yo-yo'}),
#   frozenset({'Nintendo', 'Onion'}),
#   1.0),
#  (frozenset({'Key-chain', 'Onion', 'Yo-yo'}),
#   frozenset({'Eggs', 'Nintendo'}),
#   1.0),
#  (frozenset({'Eggs', 'Onion', 'Yo-yo'}),
#   frozenset({'Key-chain', 'Nintendo'}),
#   1.0),
#  (frozenset({'Key-chain', 'Nintendo', 'Yo-yo'}),
#   frozenset({'Eggs', 'Onion'}),
#   1.0),
#  (frozenset({'Eggs', 'Nintendo', 'Yo-yo'}),
#   frozenset({'Key-chain', 'Onion'}),
#   1.0),
#  (frozenset({'Eggs', 'Key-chain', 'Nintendo'}),
#   frozenset({'Onion', 'Yo-yo'}),
#   1.0),
#  (frozenset({'Nintendo', 'Onion', 'Yo-yo'}),
#   frozenset({'Eggs', 'Key-chain'}),
#   1.0),
#  (frozenset({'Key-chain', 'Nintendo', 'Onion'}),
#   frozenset({'Eggs', 'Yo-yo'}),
#   1.0),
#  (frozenset({'Eggs', 'Nintendo', 'Onion'}),
#   frozenset({'Key-chain', 'Yo-yo'}),
#   1.0),
#  (frozenset({'Eggs', 'Yo-yo'}),
#   frozenset({'Key-chain', 'Nintendo', 'Onion'}),
#   1.0),
#  (frozenset({'Onion', 'Yo-yo'}),
#   frozenset({'Eggs', 'Key-chain', 'Nintendo'}),
#   1.0),
#  (frozenset({'Nintendo', 'Yo-yo'}),
#   frozenset({'Eggs', 'Key-chain', 'Onion'}),
#   1.0),
#  (frozenset({'Key-chain', 'Nintendo'}),
#   frozenset({'Eggs', 'Onion', 'Yo-yo'}),
#   1.0),
#  (frozenset({'Eggs', 'Nintendo'}),
#   frozenset({'Key-chain', 'Onion', 'Yo-yo'}),
#   1.0),
#  (frozenset({'Nintendo', 'Onion'}),
#   frozenset({'Eggs', 'Key-chain', 'Yo-yo'}),
#   1.0),
#  (frozenset({'Nintendo'}),
#   frozenset({'Eggs', 'Key-chain', 'Onion', 'Yo-yo'}),
#   2.0),
#  (frozenset({'Eggs', 'Key-chain', 'Mango', 'Yo-yo'}),
#   frozenset({'Nintendo', 'Onion'}),
#   1.0),
#  (frozenset({'Eggs', 'Mango', 'Onion', 'Yo-yo'}),
#   frozenset({'Key-chain', 'Nintendo'}),
#   1.0),
#  (frozenset({'Key-chain', 'Mango', 'Onion', 'Yo-yo'}),
#   frozenset({'Eggs', 'Nintendo'}),
#   1.0),
#  (frozenset({'Eggs', 'Key-chain', 'Mango', 'Onion'}),
#   frozenset({'Nintendo', 'Yo-yo'}),
#   1.0),
#  (frozenset({'Eggs', 'Mango', 'Nintendo', 'Yo-yo'}),
#   frozenset({'Key-chain', 'Onion'}),
#   1.0),
#  (frozenset({'Key-chain', 'Mango', 'Nintendo', 'Yo-yo'}),
#   frozenset({'Eggs', 'Onion'}),
#   1.0),
#  (frozenset({'Eggs', 'Key-chain', 'Mango', 'Nintendo'}),
#   frozenset({'Onion', 'Yo-yo'}),
#   1.0),
#  (frozenset({'Mango', 'Nintendo', 'Onion', 'Yo-yo'}),
#   frozenset({'Eggs', 'Key-chain'}),
#   1.0),
#  (frozenset({'Eggs', 'Mango', 'Nintendo', 'Onion'}),
#   frozenset({'Key-chain', 'Yo-yo'}),
#   1.0),
#  (frozenset({'Key-chain', 'Mango', 'Nintendo', 'Onion'}),
#   frozenset({'Eggs', 'Yo-yo'}),
#   1.0),
#  (frozenset({'Eggs', 'Mango', 'Yo-yo'}),
#   frozenset({'Key-chain', 'Nintendo', 'Onion'}),
#   1.0),
#  (frozenset({'Mango', 'Onion', 'Yo-yo'}),
#   frozenset({'Eggs', 'Key-chain', 'Nintendo'}),
#   1.0),
#  (frozenset({'Eggs', 'Mango', 'Onion'}),
#   frozenset({'Key-chain', 'Nintendo', 'Yo-yo'}),
#   1.0),
#  (frozenset({'Key-chain', 'Mango', 'Onion'}),
#   frozenset({'Eggs', 'Nintendo', 'Yo-yo'}),
#   1.0),
#  (frozenset({'Mango', 'Nintendo', 'Yo-yo'}),
#   frozenset({'Eggs', 'Key-chain', 'Onion'}),
#   1.0),
#  (frozenset({'Eggs', 'Mango', 'Nintendo'}),
#   frozenset({'Key-chain', 'Onion', 'Yo-yo'}),
#   1.0),
#  (frozenset({'Key-chain', 'Mango', 'Nintendo'}),
#   frozenset({'Eggs', 'Onion', 'Yo-yo'}),
#   1.0),
#  (frozenset({'Mango', 'Nintendo', 'Onion'}),
#   frozenset({'Eggs', 'Key-chain', 'Yo-yo'}),
#   1.0),
#  (frozenset({'Mango', 'Onion'}),
#   frozenset({'Eggs', 'Key-chain', 'Nintendo', 'Yo-yo'}),
#   1.0),
#  (frozenset({'Mango', 'Nintendo'}),
#   frozenset({'Eggs', 'Key-chain', 'Onion', 'Yo-yo'}),
#   1.0)]
